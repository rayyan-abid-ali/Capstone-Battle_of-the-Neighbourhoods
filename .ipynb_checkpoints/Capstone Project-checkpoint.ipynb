# %%
import requests
import json

# %%
CLIENT_ID = 'XAGWG4QJTV41AQHI1MABTP1Y0IWRMEVMWLSMXRVYNOEEMNAE'
CLIENT_SECRET= 'FTVL5OLLGQ552C5CSJT2JU4BYHAQQ02ZJ4TOSJSJGPH3YYKM'
VERSION=20201101

# %%
url = f'https://api.foursquare.com/v2/venues/search?&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}&ll=24.7136,46.6753'
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?&client_id=XAGWG4QJTV41AQHI1MABTP1Y0IWRMEVMWLSMXRVYNOEEMNAE&client_secret=FTVL5OLLGQ552C5CSJT2JU4BYHAQQ02ZJ4TOSJSJGPH3YYKM&v=20201101&ll=24.7136,46.6753'

# %%
riyadh_data=requests.get(url).json()

# %%
riyadh_data
# Out:
# {'meta': {'code': 200, 'requestId': '5fb0d8cff6c3124343292611'},
#  'response': {'venues': [{'id': '53b91908498ee296db5e50b7',
#     'name': 'Banque Saudi Fransi - Private Banking Head Office (البنك السعودي الفرنسي - المكتب الرئيسي)',
#     'location': {'address': 'Orouba St',
#      'lat': 24.713734167045715,
#      'lng': 46.67548061601181,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.713734167045715,
#        'lng': 46.67548061601181}],
#      'distance': 23,
#      'cc': 'SA',
#      'neighborhood': 'Al-Woroud',
#      'city': 'الرياض',
#      'state': 'منطقة الرياض\u200e',
#      'country': 'المملكة العربية السعودية',
#      'formattedAddress': ['Orouba St', 'الرياض', 'المملكة العربية السعودية']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
# ...

# %%
riyadh_data['response']['venues'][4]
# Out:
# {'id': '4f41391be4b0f7b459efed08',
#  'name': 'SHOE PALACE (قصر الأحذية) (قصر الأحذية)',
#  'location': {'address': 'Olaya St',
#   'crossStreet': 'Olaya Street',
#   'lat': 24.71317962662398,
#   'lng': 46.67582268510295,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 24.71317962662398,
#     'lng': 46.67582268510295}],
#   'distance': 70,
#   'cc': 'SA',
#   'city': 'الرياض',
#   'state': 'منطقة الرياض\u200e',
#   'country': 'المملكة العربية السعودية',
#   'formattedAddress': ['Olaya St (Olaya Street)',
#    'الرياض',
#    'المملكة العربية السعودية']},
#  'categories': [{'id': '4bf58dd8d48988d107951735',
#    'name': 'Shoe Store',
#    'pluralName': 'Shoe Stores',
#    'shortName': 'Shoes',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_shoestore_',
#     'suffix': '.png'},
#    'primary': True}],
#  'referralId': 'v-1605425359',
#  'hasPerk': False}
